# %%
# !python inference.py \
    --ckpt ./magc_ckpts/ckpts_stage2/v40_step=120999-lpips=0.3132.ckpt \
    --config configs/model/cldm_stage2.yaml \
    --input_path ./toy_datasets/real-world/val/ \
    --steps 50 \
    --batchsize 30 \
    --output_path ./metrics/ \
    --device cpu
# Out:
# /home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/torchmetrics/utilities/imports.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# No module 'xformers'. Proceeding without it.
# Global seed set to 231
# DISABLE XFORMERS!
# using device cpu
# Loading pretrained model LPIPS from /home/tobeunicorn/.cache/torch/hub/checkpoints/LPIPS_v0.1_alex-df73285e.pth
# Skipping IQA metric msssim: Metric msssim not implemented yet.
# model init...
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 865.92 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# model init over.
# loading state dict...
# loading over.
# running warmup batch...
# Encoding: 0.66s
# timesteps used in spaced sampler:
# 	[0]
# /home/tobeunicorn/MAGC/model/spaced_sampler.py:167: RuntimeWarning: divide by zero encountered in log
#   self.posterior_log_variance_clipped = np.log(
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:04<00:00,  4.68s/it]
# warmup over.
# processing batch 1:
# Encoding: 2.18s
# timesteps used in spaced sampler:
# 	[0, 20, 41, 61, 82, 102, 122, 143, 163, 183, 204, 224, 245, 265, 285, 306, 326, 347, 367, 387, 408, 428, 449, 469, 489, 510, 530, 550, 571, 591, 612, 632, 652, 673, 693, 714, 734, 754, 775, 795, 816, 836, 856, 877, 897, 917, 938, 958, 979, 999]
# Spaced Sampler: 100%|███████████████████████████| 50/50 [04:30<00:00,  5.41s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 69.21it/s]
# -----------------Cropping finished!!! Start calculating FID--------------
# Skipping FID/KID calculation: KID subset size 1000 cannot be smaller than the number of samples (input_1: 25, input_2: 25). Consider using "kid_subset_size" kwarg or "--kid-subset-size" command line key to proceed.

# %%
# !python inference.py \
    --ckpt ./magc_ckpts/ckpts_stage2/v40_step=120999-lpips=0.3132.ckpt \
    --config configs/model/cldm_stage2.yaml \
    --input_path ./toy_datasets/real-world/val/ \
    --steps 1 \
    --batchsize 1 \
    --output_path ./metrics-warmup/ \
    --device cpu
# Out:
# /home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/torchmetrics/utilities/imports.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# No module 'xformers'. Proceeding without it.
# Global seed set to 231
# DISABLE XFORMERS!
# using device cpu
# Loading pretrained model LPIPS from /home/tobeunicorn/.cache/torch/hub/checkpoints/LPIPS_v0.1_alex-df73285e.pth
# Skipping IQA metric msssim: Metric msssim not implemented yet.
# model init...
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 865.92 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# model init over.
# loading state dict...
# loading over.
# running warmup batch...
# Encoding: 2.40s
# timesteps used in spaced sampler:
# 	[0]
# /home/tobeunicorn/MAGC/model/spaced_sampler.py:167: RuntimeWarning: divide by zero encountered in log
#   self.posterior_log_variance_clipped = np.log(
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:04<00:00,  4.43s/it]
# warmup over.
# processing batch 1:
# Encoding: 0.40s
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:06<00:00,  6.15s/it]
# processing batch 2:
# Encoding: 0.28s
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:04<00:00,  4.13s/it]
# processing batch 3:
# Encoding: 1.17s
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:03<00:00,  3.80s/it]
# processing batch 4:
# Encoding: 0.21s
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:03<00:00,  3.76s/it]
# processing batch 5:
# Encoding: 0.28s
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:03<00:00,  3.49s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 77.29it/s]
# -----------------Cropping finished!!! Start calculating FID--------------
# Skipping FID/KID calculation: KID subset size 1000 cannot be smaller than the number of samples (input_1: 25, input_2: 25). Consider using "kid_subset_size" kwarg or "--kid-subset-size" command line key to proceed.
