# %%
# !python inference.py \
    --ckpt ./magc_ckpts/ckpts_stage2/v40_step=120999-lpips=0.3132.ckpt \
    --config configs/model/cldm_stage2.yaml \
    --input_path ./toy_datasets/real-world/val/ \
    --steps 50 \
    --batchsize 30 \
    --output_path ./metrics/ \
    --device cpu
# Out:
# /home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/torchmetrics/utilities/imports.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# No module 'xformers'. Proceeding without it.
# Traceback (most recent call last):
#   File "/home/tobeunicorn/MAGC/inference.py", line 15, in <module>
#     from model.cldm import ControlLDM
#   File "/home/tobeunicorn/MAGC/model/cldm.py", line 38, in <module>
#     from cal_metrics.iqa import single_iqa
#   File "/home/tobeunicorn/MAGC/cal_metrics/iqa.py", line 1, in <module>
#     import pyiqa
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/__init__.py", line 2, in <module>
#     from .archs import *
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/archs/__init__.py", line 17, in <module>
#     _arch_modules = [importlib.import_module(f'pyiqa.archs.{file_name}') for file_name in arch_filenames]
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/archs/__init__.py", line 17, in <listcomp>
#     _arch_modules = [importlib.import_module(f'pyiqa.archs.{file_name}') for file_name in arch_filenames]
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/archs/musiq_arch.py", line 19, in <module>
#     from pyiqa.data.multiscale_trans_util import get_multiscale_patches
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/data/__init__.py", line 22, in <module>
#     _dataset_modules = [importlib.import_module(f'pyiqa.data.{file_name}') for file_name in dataset_filenames]
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/data/__init__.py", line 22, in <listcomp>
#     _dataset_modules = [importlib.import_module(f'pyiqa.data.{file_name}') for file_name in dataset_filenames]
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pyiqa/data/ava_dataset.py", line 10, in <module>
#     import pandas as pd
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/core/nanops.py", line 64, in <module>
#     set_use_bottleneck(get_option("compute.use_bottleneck"))
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/_config/config.py", line 274, in __call__
#     return self.__func__(*args, **kwds)
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/_config/config.py", line 146, in _get_option
#     key = _get_single_key(pat, silent)
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/_config/config.py", line 138, in _get_single_key
#     _warn_if_deprecated(key)
#   File "/home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/pandas/_config/config.py", line 688, in _warn_if_deprecated
#     def _warn_if_deprecated(key: str) -> bool:
# KeyboardInterrupt
# ^C

# %%
# !python inference.py \
    --ckpt ./magc_ckpts/ckpts_stage2/v40_step=120999-lpips=0.3132.ckpt \
    --config configs/model/cldm_stage2.yaml \
    --input_path ./toy_datasets/real-world/val/ \
    --steps 1 \
    --batchsize 1 \
    --output_path ./metrics-warmup/ \
    --device cpu
# Out:
# /home/tobeunicorn/miniconda3/envs/magc/lib/python3.9/site-packages/torchmetrics/utilities/imports.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# No module 'xformers'. Proceeding without it.
# Global seed set to 231
# DISABLE XFORMERS!
# using device cpu
# Loading pretrained model LPIPS from /home/tobeunicorn/.cache/torch/hub/checkpoints/LPIPS_v0.1_alex-df73285e.pth
# Skipping IQA metric msssim: Metric msssim not implemented yet.
# model init...
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 865.92 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# model init over.
# loading state dict...
# loading over.
# processing batch 1:
# timesteps used in spaced sampler:
# 	[0]
# /home/tobeunicorn/MAGC/model/spaced_sampler.py:167: RuntimeWarning: divide by zero encountered in log
#   self.posterior_log_variance_clipped = np.log(
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:06<00:00,  6.54s/it]
# processing batch 2:
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:03<00:00,  3.19s/it]
# processing batch 3:
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:02<00:00,  2.68s/it]
# processing batch 4:
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:03<00:00,  3.56s/it]
# processing batch 5:
# timesteps used in spaced sampler:
# 	[0]
# Spaced Sampler: 100%|█████████████████████████████| 1/1 [00:02<00:00,  2.67s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 87.27it/s]
# -----------------Cropping finished!!! Start calculating FID--------------
# Skipping FID/KID calculation: KID subset size 1000 cannot be smaller than the number of samples (input_1: 25, input_2: 25). Consider using "kid_subset_size" kwarg or "--kid-subset-size" command line key to proceed.
