# %%
# !python scripts/make_stage1_init_weight.py \
--cldm_config configs/model/cldm_stage2.yaml \
--sd_weight pretrained/v40_step=120999-lpips=0.3132.ckpt \
--output pretrained/init_stage1.ckpt
# Out:
# No module 'xformers'. Proceeding without it.
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 865.92 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# copy weights: betas -> betas
# copy weights: alphas_cumprod -> alphas_cumprod
# copy weights: alphas_cumprod_prev -> alphas_cumprod_prev
# copy weights: sqrt_alphas_cumprod -> sqrt_alphas_cumprod
# copy weights: sqrt_one_minus_alphas_cumprod -> sqrt_one_minus_alphas_cumprod
# copy weights: log_one_minus_alphas_cumprod -> log_one_minus_alphas_cumprod
# copy weights: sqrt_recip_alphas_cumprod -> sqrt_recip_alphas_cumprod
# copy weights: sqrt_recipm1_alphas_cumprod -> sqrt_recipm1_alphas_cumprod
# copy weights: posterior_variance -> posterior_variance
# copy weights: posterior_log_variance_clipped -> posterior_log_variance_clipped
# ...

# %%
# !python train.py \
--config configs/train_cldm_stage1.yaml
# Out:
# Seed set to 231
# No module 'xformers'. Proceeding without it.
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 865.92 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Traceback (most recent call last):
#   File "/home/tobeunicorn/MAGC/train.py", line 44, in <module>
#     main()
#   File "/home/tobeunicorn/MAGC/train.py", line 33, in main
#     load_state_dict(model, torch.load(config.model.resume, map_location="cpu", weights_only=False), strict=False)
#   File "/home/tobeunicorn/miniconda3/envs/magc310/lib/python3.10/site-packages/torch/serialization.py", line 1479, in load
#     with _open_file_like(f, "rb") as opened_file:
#   File "/home/tobeunicorn/miniconda3/envs/magc310/lib/python3.10/site-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
# ...
